# %% [markdown]
# # Exercise 4: Ridge Regression on the Franke function  with resampling (score 20 points)
#
# Write your own code for the Ridge method, either using matrix
# inversion or the singular value decomposition as done in the previous
# exercise. Perform the same bootstrap analysis as in the
# Exercise 2  (for the same polynomials) and the cross-validation  in exercise 3 but now for different values of $\lambda$. Compare and
# analyze your results with those obtained in exercises 1-3. Study the
# dependence on $\lambda$.
#
# Study also the bias-variance trade-off as function of various values of
# the parameter $\lambda$. For the bias-variance trade-off, use the **bootstrap** resampling method. Comment your results.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.utils import resample
from sklearn.model_selection import  train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter



def FrankeFunction(x,y):
    term1 = 0.75*np.exp(-(0.25*(9*x-2)**2) - 0.25*((9*y-2)**2))
    term2 = 0.75*np.exp(-((9*x+1)**2)/49.0 - 0.1*(9*y+1))
    term3 = 0.5*np.exp(-(9*x-7)**2/4.0 - 0.25*((9*y-3)**2))
    term4 = -0.2*np.exp(-(9*x-4)**2 - (9*y-7)**2)
    return term1 + term2 + term3 + term4

def FrankeFunctionWithNoise(x,y):
    term1 = 0.75*np.exp(-(0.25*(9*x-2)**2) - 0.25*((9*y-2)**2))
    term2 = 0.75*np.exp(-((9*x+1)**2)/49.0 - 0.1*(9*y+1))
    term3 = 0.5*np.exp(-(9*x-7)**2/4.0 - 0.25*((9*y-3)**2))
    term4 = -0.2*np.exp(-(9*x-4)**2 - (9*y-7)**2)
    noise = np.random.normal(0, 0.1, len(x)*len(x))
    noise = noise.reshape(len(x),len(x))
    return term1 + term2 + term3 + term4 + noise


def create_X(x, y, n ):
    if len(x.shape) > 1:
        x = np.ravel(x)
        y = np.ravel(y)

    N = len(x)
    l = int((n+1)*(n+2)/2) # Number of elements in beta
    X = np.ones((N,l))

    for i in range(1,n+1):
        q = int((i)*(i+1)/2)
        for k in range(i+1):
            X[:,q+k] = (x**(i-k))*(y**k)
    return X

def R2(y_data, y_model):
    return 1 - np.sum((y_data - y_model) ** 2) / np.sum((y_data - np.mean(y_data)) ** 2)

# %%
################# Parameters #################

n = 20  #number of data
polynomial = 10 #polynomial degree
list_degree = [5, 6]
k = 5 #number of splits
n_bootstraps = 20
nlambdas = 100
lambdas = np.logspace(-3, 5, nlambdas)

#############################################

x = np.linspace(0, 1, n)
y = np.linspace(0, 1, n)
x, y = np.meshgrid(x, y)
z = FrankeFunctionWithNoise(x, y)
z = z.ravel()


x_y = np.empty((len(x)*len(x), 2))
x_y[:, 0] = x.ravel()
x_y[:, 1] = y.ravel()
x_y_train, x_y_test, z_train, z_test = train_test_split(x_y, z.ravel(), test_size=0.2)


kfold = KFold(n_splits=k)

min_error = []
min_lambdas = []

for degree in list_degree:

    scores_KFold = np.zeros((nlambdas, k))
    estimated_mse_sklearn = np.zeros(nlambdas)


    error = np.zeros(lambdas.shape[0])
    bias = np.zeros(lambdas.shape[0])
    variance = np.zeros(lambdas.shape[0])


    j = 0
    
    
    poly = PolynomialFeatures(degree=degree)
    
    
    for l in lambdas:

        ridge = Ridge(alpha=l, fit_intercept=False)
        pred_test = np.empty((z_test.shape[0], n_bootstraps))
        pred_train = np.empty((z_train.shape[0], n_bootstraps))

        
        
        for i in range(n_bootstraps):
            x_y_, z_ = resample(x_y_train, z_train)
            X_train = create_X(x_y_[:, 0], x_y_[:, 1], degree)
            X_test = create_X(x_y_test[:, 0], x_y_test[:, 1], degree)
            RidgeBeta = np.linalg.pinv(X_train.T.dot(X_train) + l * np.eye(X_train.T.dot(X_train).shape[0])).dot(X_train.T).dot(z_)
            pred_test[:, i] = X_test @ RidgeBeta
            pred_train[:, i] = X_train @ RidgeBeta


        z_pred_kfold  = np.empty((int(z.shape[0] / k), k))
        h = 0

     
        
        for train_index, test_index in kfold.split(x_y):
            x_train_kfold, x_test_kfold  = x_y[train_index], x_y[test_index]
            z_train_kfold, z_test_kfold = z[train_index], z[test_index]

            X_train = poly.fit_transform(x_train_kfold)
            ridge.fit(X_train, z_train_kfold)
            Xtest = poly.fit_transform(x_test_kfold)
            zpred = ridge.predict(Xtest)
            scores_KFold[j, h] = np.sum((zpred - z_test_kfold) ** 2) / np.size(zpred)
            z_pred_kfold[:, h] = zpred
            h += 1

        
        
        
        X = poly.fit_transform(x_y)
        estimated_mse_folds = cross_val_score(ridge, X, z, scoring='neg_mean_squared_error',cv=kfold)
        estimated_mse_sklearn[j] = np.mean(-estimated_mse_folds)


        error[j] = np.mean(np.mean((z_test.reshape(z_test.shape[0], 1) - pred_test) ** 2, axis=1, keepdims=True))
        bias[j] = np.mean((z_test.reshape(z_test.shape[0], 1) - np.mean(pred_test, axis=1, keepdims=True)) ** 2)
        variance[j] = np.mean(np.var(pred_test, axis=1, keepdims=True))


        print('Polynomial degree:', degree)
        print('Log10(Lambda):',np.log10(l) )
        print("---------Bootstrap---------")
        print('Error:', error[j])
        print('Bias^2:', bias[j])
        print('Var:', variance[j])
        print('{} >= {} + {} = {}'.format(error[j], bias[j], variance[j], bias[j] + variance[j]))
        print("---------Cross Validation---------")
        print('Error_sklearn:', estimated_mse_sklearn[j])
        print("\n\n")

        j +=1

   

    estimated_mse_KFold = np.mean(scores_KFold, axis=1)
    
    min_error.append(min(estimated_mse_KFold))
    min_lambdas.append(lambdas[estimated_mse_KFold.index(np.min(estimated_mse_KFold))])
    
    
    fig, axs = plt.subplots(2, 1, constrained_layout=True)
    axs[0].plot(np.log10(lambdas), error, label='Error')
    axs[0].plot(np.log10(lambdas), bias, '--', label='bias')
    axs[0].plot(np.log10(lambdas), variance, label='Variance')
    axs[0].set_title(" Boostraps Bias-variance trade-off for polynomial degree = " + str(degree))
    axs[0].legend()
    axs[0].grid()

    axs[1].plot(np.log10(lambdas), estimated_mse_KFold, label='estimated_mse_KFold')
    axs[1].plot(np.log10(lambdas), estimated_mse_sklearn,'r--',  label='estimated_mse_sklearn')
    axs[1].set_title(" Cross Validation for polynomial degree = " + str(degree))
    axs[1].legend()
    axs[1].grid()

plt.show()
# Out:
# Polynomial degree: 5
# Log10(Lambda): -3.0
# ---------Bootstrap---------
# Error: 0.012088901530853624
# Bias^2: 0.011309632216188477
# Var: 0.0007792693146651495
# 0.012088901530853624 >= 0.011309632216188477 + 0.0007792693146651495 = 0.012088901530853626
# ---------Cross Validation---------
# Error_sklearn: 0.13201384823523682
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -2.919191919191919
# ---------Bootstrap---------
# Error: 0.01231127278350244
# Bias^2: 0.011690768346101407
# Var: 0.0006205044374010336
# 0.01231127278350244 >= 0.011690768346101407 + 0.0006205044374010336 = 0.01231127278350244
# ---------Cross Validation---------
# Error_sklearn: 0.13330120162875964
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -2.8383838383838382
# ---------Bootstrap---------
# Error: 0.011968227312546296
# Bias^2: 0.011252454179774923
# Var: 0.0007157731327713732
# 0.011968227312546296 >= 0.011252454179774923 + 0.0007157731327713732 = 0.011968227312546296
# ---------Cross Validation---------
# Error_sklearn: 0.13396673448469107
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -2.757575757575758
# ---------Bootstrap---------
# Error: 0.012077754572395464
# Bias^2: 0.011367623146822926
# Var: 0.0007101314255725376
# 0.012077754572395464 >= 0.011367623146822926 + 0.0007101314255725376 = 0.012077754572395464
# ---------Cross Validation---------
# Error_sklearn: 0.1339898787689262
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -2.676767676767677
# ---------Bootstrap---------
# Error: 0.012219126824045945
# Bias^2: 0.011328126752390658
# Var: 0.0008910000716552856
# 0.012219126824045945 >= 0.011328126752390658 + 0.0008910000716552856 = 0.012219126824045943
# ---------Cross Validation---------
# Error_sklearn: 0.1333578599346046
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -2.595959595959596
# ---------Bootstrap---------
# Error: 0.012101932746632824
# Bias^2: 0.011468568695196097
# Var: 0.0006333640514367301
# 0.012101932746632824 >= 0.011468568695196097 + 0.0006333640514367301 = 0.012101932746632828
# ---------Cross Validation---------
# Error_sklearn: 0.1320685600346695
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -2.515151515151515
# ---------Bootstrap---------
# Error: 0.012299383143345482
# Bias^2: 0.011601325364673181
# Var: 0.000698057778672303
# 0.012299383143345482 >= 0.011601325364673181 + 0.000698057778672303 = 0.012299383143345485
# ---------Cross Validation---------
# Error_sklearn: 0.13013187791500497
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -2.4343434343434343
# ---------Bootstrap---------
# Error: 0.011857777630420008
# Bias^2: 0.011290712495480505
# Var: 0.0005670651349395032
# 0.011857777630420008 >= 0.011290712495480505 + 0.0005670651349395032 = 0.011857777630420008
# ---------Cross Validation---------
# Error_sklearn: 0.12756940669348416
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -2.3535353535353534
# ---------Bootstrap---------
# Error: 0.012179902478276996
# Bias^2: 0.011614957673131834
# Var: 0.0005649448051451613
# 0.012179902478276996 >= 0.011614957673131834 + 0.0005649448051451613 = 0.012179902478276996
# ---------Cross Validation---------
# Error_sklearn: 0.1244127660156042
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -2.2727272727272725
# ---------Bootstrap---------
# Error: 0.012504777995422817
# Bias^2: 0.011884624110598097
# Var: 0.0006201538848247204
# 0.012504777995422817 >= 0.011884624110598097 + 0.0006201538848247204 = 0.012504777995422817
# ---------Cross Validation---------
# Error_sklearn: 0.12070128160327749
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -2.191919191919192
# ---------Bootstrap---------
# Error: 0.012453228054373973
# Bias^2: 0.01183348584125573
# Var: 0.0006197422131182455
# 0.012453228054373973 >= 0.01183348584125573 + 0.0006197422131182455 = 0.012453228054373974
# ---------Cross Validation---------
# Error_sklearn: 0.11647980593955158
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -2.111111111111111
# ---------Bootstrap---------
# Error: 0.012891518403221997
# Bias^2: 0.01219501920605944
# Var: 0.0006964991971625564
# 0.012891518403221997 >= 0.01219501920605944 + 0.0006964991971625564 = 0.012891518403221997
# ---------Cross Validation---------
# Error_sklearn: 0.11179734717339321
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -2.0303030303030303
# ---------Bootstrap---------
# Error: 0.013050029517144502
# Bias^2: 0.012447529662653148
# Var: 0.0006024998544913509
# 0.013050029517144502 >= 0.012447529662653148 + 0.0006024998544913509 = 0.013050029517144499
# ---------Cross Validation---------
# Error_sklearn: 0.10670692252460849
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -1.9494949494949494
# ---------Bootstrap---------
# Error: 0.013034375172759577
# Bias^2: 0.012362215661782996
# Var: 0.0006721595109765796
# 0.013034375172759577 >= 0.012362215661782996 + 0.0006721595109765796 = 0.013034375172759575
# ---------Cross Validation---------
# Error_sklearn: 0.10126678272371767
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -1.8686868686868685
# ---------Bootstrap---------
# Error: 0.01320615556491139
# Bias^2: 0.012764969352662114
# Var: 0.0004411862122492757
# 0.01320615556491139 >= 0.012764969352662114 + 0.0004411862122492757 = 0.01320615556491139
# ---------Cross Validation---------
# Error_sklearn: 0.09554291145636902
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -1.7878787878787878
# ---------Bootstrap---------
# Error: 0.013121098881516632
# Bias^2: 0.012444504733898711
# Var: 0.0006765941476179203
# 0.013121098881516632 >= 0.012444504733898711 + 0.0006765941476179203 = 0.013121098881516632
# ---------Cross Validation---------
# Error_sklearn: 0.08961246975290002
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -1.707070707070707
# ---------Bootstrap---------
# Error: 0.01329925737747797
# Bias^2: 0.01276911555998384
# Var: 0.0005301418174941326
# 0.01329925737747797 >= 0.01276911555998384 + 0.0005301418174941326 = 0.013299257377477973
# ---------Cross Validation---------
# Error_sklearn: 0.08356759032839399
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -1.626262626262626
# ---------Bootstrap---------
# Error: 0.01355674860913654
# Bias^2: 0.013013646325521789
# Var: 0.0005431022836147493
# 0.01355674860913654 >= 0.013013646325521789 + 0.0005431022836147493 = 0.013556748609136538
# ---------Cross Validation---------
# Error_sklearn: 0.07751862916657988
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -1.5454545454545454
# ---------Bootstrap---------
# Error: 0.013367188713788272
# Bias^2: 0.012939421893250463
# Var: 0.0004277668205378067
# 0.013367188713788272 >= 0.012939421893250463 + 0.0004277668205378067 = 0.01336718871378827
# ---------Cross Validation---------
# Error_sklearn: 0.07159572244800443
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -1.4646464646464645
# ---------Bootstrap---------
# Error: 0.013314101067656283
# Bias^2: 0.012803451556933987
# Var: 0.0005106495107222998
# 0.013314101067656283 >= 0.012803451556933987 + 0.0005106495107222998 = 0.013314101067656287
# ---------Cross Validation---------
# Error_sklearn: 0.06594741332299872
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -1.3838383838383836
# ---------Bootstrap---------
# Error: 0.013379942010520281
# Bias^2: 0.012897293166335175
# Var: 0.00048264884418510595
# 0.013379942010520281 >= 0.012897293166335175 + 0.00048264884418510595 = 0.013379942010520281
# ---------Cross Validation---------
# Error_sklearn: 0.06073535582254854
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -1.303030303030303
# ---------Bootstrap---------
# Error: 0.01348732966078874
# Bias^2: 0.013017304071574642
# Var: 0.0004700255892140996
# 0.01348732966078874 >= 0.013017304071574642 + 0.0004700255892140996 = 0.013487329660788742
# ---------Cross Validation---------
# Error_sklearn: 0.0561247541654092
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -1.222222222222222
# ---------Bootstrap---------
# Error: 0.01345430439535798
# Bias^2: 0.013090798502444679
# Var: 0.00036350589291330387
# 0.01345430439535798 >= 0.013090798502444679 + 0.00036350589291330387 = 0.013454304395357983
# ---------Cross Validation---------
# Error_sklearn: 0.05227118579560062
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -1.1414141414141412
# ---------Bootstrap---------
# Error: 0.013716141433299514
# Bias^2: 0.01325228355487924
# Var: 0.00046385787842027367
# 0.013716141433299514 >= 0.01325228355487924 + 0.00046385787842027367 = 0.013716141433299514
# ---------Cross Validation---------
# Error_sklearn: 0.0493055332541892
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -1.0606060606060606
# ---------Bootstrap---------
# Error: 0.013459390461749923
# Bias^2: 0.012983008476927765
# Var: 0.000476381984822157
# 0.013459390461749923 >= 0.012983008476927765 + 0.000476381984822157 = 0.013459390461749923
# ---------Cross Validation---------
# Error_sklearn: 0.04731953908328413
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -0.9797979797979797
# ---------Bootstrap---------
# Error: 0.013450103695871112
# Bias^2: 0.013016714455929862
# Var: 0.00043338923994125134
# 0.013450103695871112 >= 0.013016714455929862 + 0.00043338923994125134 = 0.013450103695871114
# ---------Cross Validation---------
# Error_sklearn: 0.04635465921339117
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -0.8989898989898988
# ---------Bootstrap---------
# Error: 0.013693991028818547
# Bias^2: 0.01319745200125937
# Var: 0.0004965390275591822
# 0.013693991028818547 >= 0.01319745200125937 + 0.0004965390275591822 = 0.01369399102881855
# ---------Cross Validation---------
# Error_sklearn: 0.04639629826949633
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -0.8181818181818179
# ---------Bootstrap---------
# Error: 0.013293369412122022
# Bias^2: 0.012816230481709396
# Var: 0.0004771389304126255
# 0.013293369412122022 >= 0.012816230481709396 + 0.0004771389304126255 = 0.013293369412122022
# ---------Cross Validation---------
# Error_sklearn: 0.04737434493480812
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -0.737373737373737
# ---------Bootstrap---------
# Error: 0.01336357792944371
# Bias^2: 0.012908722487259942
# Var: 0.0004548554421837699
# 0.01336357792944371 >= 0.012908722487259942 + 0.0004548554421837699 = 0.013363577929443711
# ---------Cross Validation---------
# Error_sklearn: 0.04916959797638448
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -0.6565656565656566
# ---------Bootstrap---------
# Error: 0.013398227890870246
# Bias^2: 0.013008792531308128
# Var: 0.0003894353595621191
# 0.013398227890870246 >= 0.013008792531308128 + 0.0003894353595621191 = 0.013398227890870246
# ---------Cross Validation---------
# Error_sklearn: 0.05162462239397882
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -0.5757575757575757
# ---------Bootstrap---------
# Error: 0.013414674470917803
# Bias^2: 0.01304392145183983
# Var: 0.00037075301907797355
# 0.013414674470917803 >= 0.01304392145183983 + 0.00037075301907797355 = 0.013414674470917803
# ---------Cross Validation---------
# Error_sklearn: 0.054557064453584936
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -0.49494949494949475
# ---------Bootstrap---------
# Error: 0.013515632121962001
# Bias^2: 0.01310753311445963
# Var: 0.0004080990075023746
# 0.013515632121962001 >= 0.01310753311445963 + 0.0004080990075023746 = 0.013515632121962004
# ---------Cross Validation---------
# Error_sklearn: 0.05777349525122011
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -0.4141414141414139
# ---------Bootstrap---------
# Error: 0.013943232010058182
# Bias^2: 0.013498165660671158
# Var: 0.00044506634938702835
# 0.013943232010058182 >= 0.013498165660671158 + 0.00044506634938702835 = 0.013943232010058187
# ---------Cross Validation---------
# Error_sklearn: 0.061082269890626505
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -0.33333333333333304
# ---------Bootstrap---------
# Error: 0.014184117741227974
# Bias^2: 0.013790620270256515
# Var: 0.00039349747097145794
# 0.014184117741227974 >= 0.013790620270256515 + 0.00039349747097145794 = 0.014184117741227973
# ---------Cross Validation---------
# Error_sklearn: 0.06430445538341467
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -0.25252525252525215
# ---------Bootstrap---------
# Error: 0.014366540632661202
# Bias^2: 0.013837932487602591
# Var: 0.0005286081450586097
# 0.014366540632661202 >= 0.013837932487602591 + 0.0005286081450586097 = 0.0143665406326612
# ---------Cross Validation---------
# Error_sklearn: 0.06728241688969085
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -0.1717171717171713
# ---------Bootstrap---------
# Error: 0.014767803004008404
# Bias^2: 0.014453309605599516
# Var: 0.000314493398408884
# 0.014767803004008404 >= 0.014453309605599516 + 0.000314493398408884 = 0.0147678030040084
# ---------Cross Validation---------
# Error_sklearn: 0.06988606173627056
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -0.0909090909090908
# ---------Bootstrap---------
# Error: 0.014889137578113961
# Bias^2: 0.014534444116608026
# Var: 0.0003546934615059348
# 0.014889137578113961 >= 0.014534444116608026 + 0.0003546934615059348 = 0.014889137578113961
# ---------Cross Validation---------
# Error_sklearn: 0.07201698834516332
#
#
#
# Polynomial degree: 5
# Log10(Lambda): -0.010101010101009927
# ---------Bootstrap---------
# Error: 0.015497781656889784
# Bias^2: 0.015041457181396545
# Var: 0.0004563244754932378
# 0.015497781656889784 >= 0.015041457181396545 + 0.0004563244754932378 = 0.015497781656889783
# ---------Cross Validation---------
# Error_sklearn: 0.07361087162966909
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 0.07070707070707095
# ---------Bootstrap---------
# Error: 0.015867540246911768
# Bias^2: 0.015441288447289026
# Var: 0.00042625179962274085
# 0.015867540246911768 >= 0.015441288447289026 + 0.00042625179962274085 = 0.015867540246911768
# ---------Cross Validation---------
# Error_sklearn: 0.07463835856957955
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 0.1515151515151518
# ---------Bootstrap---------
# Error: 0.01661051550528215
# Bias^2: 0.016287082472300242
# Var: 0.00032343303298190684
# 0.01661051550528215 >= 0.016287082472300242 + 0.00032343303298190684 = 0.01661051550528215
# ---------Cross Validation---------
# Error_sklearn: 0.07510459195582955
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 0.2323232323232327
# ---------Bootstrap---------
# Error: 0.016847865123632268
# Bias^2: 0.016452455732695874
# Var: 0.00039540939093639404
# 0.016847865123632268 >= 0.016452455732695874 + 0.00039540939093639404 = 0.016847865123632268
# ---------Cross Validation---------
# Error_sklearn: 0.07504729611614855
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 0.31313131313131354
# ---------Bootstrap---------
# Error: 0.017904652789055925
# Bias^2: 0.01744904160578208
# Var: 0.00045561118327384876
# 0.017904652789055925 >= 0.01744904160578208 + 0.00045561118327384876 = 0.01790465278905593
# ---------Cross Validation---------
# Error_sklearn: 0.07453323209544707
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 0.39393939393939403
# ---------Bootstrap---------
# Error: 0.018347580260928163
# Bias^2: 0.01791351477897989
# Var: 0.00043406548194827233
# 0.018347580260928163 >= 0.01791351477897989 + 0.00043406548194827233 = 0.018347580260928163
# ---------Cross Validation---------
# Error_sklearn: 0.07365284357262855
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 0.4747474747474749
# ---------Bootstrap---------
# Error: 0.019038709464270522
# Bias^2: 0.018627843598743983
# Var: 0.00041086586552654383
# 0.019038709464270522 >= 0.018627843598743983 + 0.00041086586552654383 = 0.019038709464270526
# ---------Cross Validation---------
# Error_sklearn: 0.07251311695139688
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 0.5555555555555558
# ---------Bootstrap---------
# Error: 0.01984764907255956
# Bias^2: 0.019463098310332584
# Var: 0.0003845507622269779
# 0.01984764907255956 >= 0.019463098310332584 + 0.0003845507622269779 = 0.01984764907255956
# ---------Cross Validation---------
# Error_sklearn: 0.0712290540266867
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 0.6363636363636367
# ---------Bootstrap---------
# Error: 0.020716586377205796
# Bias^2: 0.020441540923958727
# Var: 0.00027504545324706485
# 0.020716586377205796 >= 0.020441540923958727 + 0.00027504545324706485 = 0.020716586377205793
# ---------Cross Validation---------
# Error_sklearn: 0.06991460993002666
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 0.7171717171717176
# ---------Bootstrap---------
# Error: 0.021724241039191433
# Bias^2: 0.021308841941384996
# Var: 0.00041539909780643634
# 0.021724241039191433 >= 0.021308841941384996 + 0.00041539909780643634 = 0.021724241039191433
# ---------Cross Validation---------
# Error_sklearn: 0.06867432703837575
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 0.7979797979797985
# ---------Bootstrap---------
# Error: 0.022173447582671695
# Bias^2: 0.021917026143150352
# Var: 0.0002564214395213425
# 0.022173447582671695 >= 0.021917026143150352 + 0.0002564214395213425 = 0.022173447582671695
# ---------Cross Validation---------
# Error_sklearn: 0.06759702872098816
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 0.8787878787878789
# ---------Bootstrap---------
# Error: 0.023834776458597988
# Bias^2: 0.023431194828535767
# Var: 0.00040358163006221933
# 0.023834776458597988 >= 0.023431194828535767 + 0.00040358163006221933 = 0.023834776458597984
# ---------Cross Validation---------
# Error_sklearn: 0.06675271219987093
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 0.9595959595959598
# ---------Bootstrap---------
# Error: 0.025083711965068346
# Bias^2: 0.02472361941669385
# Var: 0.00036009254837449334
# 0.025083711965068346 >= 0.02472361941669385 + 0.00036009254837449334 = 0.025083711965068343
# ---------Cross Validation---------
# Error_sklearn: 0.0661931970607698
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 1.0404040404040407
# ---------Bootstrap---------
# Error: 0.025892385147619833
# Bias^2: 0.025580417740459042
# Var: 0.0003119674071607974
# 0.025892385147619833 >= 0.025580417740459042 + 0.0003119674071607974 = 0.02589238514761984
# ---------Cross Validation---------
# Error_sklearn: 0.06595627295460293
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 1.121212121212122
# ---------Bootstrap---------
# Error: 0.027523119414001374
# Bias^2: 0.027160397418312054
# Var: 0.00036272199568932546
# 0.027523119414001374 >= 0.027160397418312054 + 0.00036272199568932546 = 0.02752311941400138
# ---------Cross Validation---------
# Error_sklearn: 0.0660722644468141
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 1.2020202020202024
# ---------Bootstrap---------
# Error: 0.02897659863632388
# Bias^2: 0.02871752462943907
# Var: 0.000259074006884808
# 0.02897659863632388 >= 0.02871752462943907 + 0.000259074006884808 = 0.028976598636323878
# ---------Cross Validation---------
# Error_sklearn: 0.06657132354428805
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 1.2828282828282829
# ---------Bootstrap---------
# Error: 0.030880240544166847
# Bias^2: 0.030565491602657417
# Var: 0.00031474894150942555
# 0.030880240544166847 >= 0.030565491602657417 + 0.00031474894150942555 = 0.030880240544166843
# ---------Cross Validation---------
# Error_sklearn: 0.06748953694411274
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 1.3636363636363642
# ---------Bootstrap---------
# Error: 0.032832891825463215
# Bias^2: 0.032526387179443284
# Var: 0.00030650464601992476
# 0.032832891825463215 >= 0.032526387179443284 + 0.00030650464601992476 = 0.03283289182546321
# ---------Cross Validation---------
# Error_sklearn: 0.06887215265613691
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 1.4444444444444446
# ---------Bootstrap---------
# Error: 0.03460333721346294
# Bias^2: 0.03435710351536568
# Var: 0.00024623369809726657
# 0.03460333721346294 >= 0.03435710351536568 + 0.00024623369809726657 = 0.03460333721346295
# ---------Cross Validation---------
# Error_sklearn: 0.07077283940215458
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 1.525252525252526
# ---------Bootstrap---------
# Error: 0.035934891271934354
# Bias^2: 0.03566280534764256
# Var: 0.0002720859242918012
# 0.035934891271934354 >= 0.03566280534764256 + 0.0002720859242918012 = 0.03593489127193436
# ---------Cross Validation---------
# Error_sklearn: 0.07324876389754606
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 1.6060606060606064
# ---------Bootstrap---------
# Error: 0.03851824860395037
# Bias^2: 0.0381858684598503
# Var: 0.0003323801441000569
# 0.03851824860395037 >= 0.0381858684598503 + 0.0003323801441000569 = 0.03851824860395036
# ---------Cross Validation---------
# Error_sklearn: 0.07635222961490344
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 1.6868686868686869
# ---------Bootstrap---------
# Error: 0.04077336608927225
# Bias^2: 0.04053353339378869
# Var: 0.00023983269548356035
# 0.04077336608927225 >= 0.04053353339378869 + 0.00023983269548356035 = 0.040773366089272255
# ---------Cross Validation---------
# Error_sklearn: 0.08012046549507364
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 1.7676767676767682
# ---------Bootstrap---------
# Error: 0.044170892732773935
# Bias^2: 0.04389848211184807
# Var: 0.000272410620925876
# 0.044170892732773935 >= 0.04389848211184807 + 0.000272410620925876 = 0.04417089273277394
# ---------Cross Validation---------
# Error_sklearn: 0.08456569013075198
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 1.8484848484848486
# ---------Bootstrap---------
# Error: 0.047473951219996126
# Bias^2: 0.04729957291966354
# Var: 0.00017437830033259486
# 0.047473951219996126 >= 0.04729957291966354 + 0.00017437830033259486 = 0.04747395121999613
# ---------Cross Validation---------
# Error_sklearn: 0.08966766608565267
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 1.92929292929293
# ---------Bootstrap---------
# Error: 0.05149702720826075
# Bias^2: 0.05128959821981571
# Var: 0.00020742898844502796
# 0.05149702720826075 >= 0.05128959821981571 + 0.00020742898844502796 = 0.05149702720826074
# ---------Cross Validation---------
# Error_sklearn: 0.09537056332071506
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 2.0101010101010104
# ---------Bootstrap---------
# Error: 0.05464175076722851
# Bias^2: 0.05438100229556022
# Var: 0.0002607484716682763
# 0.05464175076722851 >= 0.05438100229556022 + 0.0002607484716682763 = 0.0546417507672285
# ---------Cross Validation---------
# Error_sklearn: 0.10158515311229435
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 2.0909090909090917
# ---------Bootstrap---------
# Error: 0.058993824849541875
# Bias^2: 0.058828195727233815
# Var: 0.00016562912230805586
# 0.058993824849541875 >= 0.058828195727233815 + 0.00016562912230805586 = 0.05899382484954187
# ---------Cross Validation---------
# Error_sklearn: 0.10819632600907929
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 2.171717171717172
# ---------Bootstrap---------
# Error: 0.06405935228415294
# Bias^2: 0.06393545305211318
# Var: 0.00012389923203975917
# 0.06405935228415294 >= 0.06393545305211318 + 0.00012389923203975917 = 0.06405935228415294
# ---------Cross Validation---------
# Error_sklearn: 0.11507487453659418
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 2.2525252525252526
# ---------Bootstrap---------
# Error: 0.06850251216707162
# Bias^2: 0.06835708054501874
# Var: 0.00014543162205288865
# 0.06850251216707162 >= 0.06835708054501874 + 0.00014543162205288865 = 0.06850251216707162
# ---------Cross Validation---------
# Error_sklearn: 0.12209160096690778
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 2.333333333333334
# ---------Bootstrap---------
# Error: 0.07302278816382503
# Bias^2: 0.07295034999677617
# Var: 7.243816704885141e-05
# 0.07302278816382503 >= 0.07295034999677617 + 7.243816704885141e-05 = 0.07302278816382503
# ---------Cross Validation---------
# Error_sklearn: 0.129131274145951
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 2.4141414141414144
# ---------Bootstrap---------
# Error: 0.07897569403880231
# Bias^2: 0.0788119951866828
# Var: 0.00016369885211952017
# 0.07897569403880231 >= 0.0788119951866828 + 0.00016369885211952017 = 0.07897569403880232
# ---------Cross Validation---------
# Error_sklearn: 0.13610389588075808
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 2.4949494949494957
# ---------Bootstrap---------
# Error: 0.08407360330368964
# Bias^2: 0.08400789660550627
# Var: 6.570669818337492e-05
# 0.08407360330368964 >= 0.08400789660550627 + 6.570669818337492e-05 = 0.08407360330368964
# ---------Cross Validation---------
# Error_sklearn: 0.14295119947893298
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 2.575757575757576
# ---------Bootstrap---------
# Error: 0.0892775333267276
# Bias^2: 0.0891306824519932
# Var: 0.00014685087473439827
# 0.0892775333267276 >= 0.0891306824519932 + 0.00014685087473439827 = 0.0892775333267276
# ---------Cross Validation---------
# Error_sklearn: 0.14964723250534823
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 2.6565656565656575
# ---------Bootstrap---------
# Error: 0.09526686998325047
# Bias^2: 0.09517915065083352
# Var: 8.771933241694963e-05
# 0.09526686998325047 >= 0.09517915065083352 + 8.771933241694963e-05 = 0.09526686998325047
# ---------Cross Validation---------
# Error_sklearn: 0.15619309524113542
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 2.737373737373738
# ---------Bootstrap---------
# Error: 0.10075138806934861
# Bias^2: 0.10066862738136675
# Var: 8.27606879818514e-05
# 0.10075138806934861 >= 0.10066862738136675 + 8.27606879818514e-05 = 0.10075138806934861
# ---------Cross Validation---------
# Error_sklearn: 0.1626071482838004
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 2.8181818181818183
# ---------Bootstrap---------
# Error: 0.10624330953064935
# Bias^2: 0.10618637073058515
# Var: 5.693880006421172e-05
# 0.10624330953064935 >= 0.10618637073058515 + 5.693880006421172e-05 = 0.10624330953064937
# ---------Cross Validation---------
# Error_sklearn: 0.16891296703657704
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 2.8989898989898997
# ---------Bootstrap---------
# Error: 0.11172424059643749
# Bias^2: 0.111663298897497
# Var: 6.094169894049448e-05
# 0.11172424059643749 >= 0.111663298897497 + 6.094169894049448e-05 = 0.1117242405964375
# ---------Cross Validation---------
# Error_sklearn: 0.17512774846914492
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 2.97979797979798
# ---------Bootstrap---------
# Error: 0.11784023821257979
# Bias^2: 0.1178066372205739
# Var: 3.360099200588243e-05
# 0.11784023821257979 >= 0.1178066372205739 + 3.360099200588243e-05 = 0.11784023821257979
# ---------Cross Validation---------
# Error_sklearn: 0.1812536307613841
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 3.0606060606060614
# ---------Bootstrap---------
# Error: 0.12473469601724167
# Bias^2: 0.1247092207371894
# Var: 2.547528005228708e-05
# 0.12473469601724167 >= 0.1247092207371894 + 2.547528005228708e-05 = 0.12473469601724169
# ---------Cross Validation---------
# Error_sklearn: 0.18727352452106114
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 3.141414141414142
# ---------Bootstrap---------
# Error: 0.1300409120151621
# Bias^2: 0.13000921074361246
# Var: 3.170127154959877e-05
# 0.1300409120151621 >= 0.13000921074361246 + 3.170127154959877e-05 = 0.13004091201516207
# ---------Cross Validation---------
# Error_sklearn: 0.1931518322382214
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 3.2222222222222223
# ---------Bootstrap---------
# Error: 0.1350699996580682
# Bias^2: 0.13504224463429365
# Var: 2.7755023774590357e-05
# 0.1350699996580682 >= 0.13504224463429365 + 2.7755023774590357e-05 = 0.13506999965806823
# ---------Cross Validation---------
# Error_sklearn: 0.19883923136661086
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 3.3030303030303036
# ---------Bootstrap---------
# Error: 0.1413408468844191
# Bias^2: 0.14133044775910555
# Var: 1.0399125313555187e-05
# 0.1413408468844191 >= 0.14133044775910555 + 1.0399125313555187e-05 = 0.1413408468844191
# ---------Cross Validation---------
# Error_sklearn: 0.20427987351508525
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 3.383838383838384
# ---------Bootstrap---------
# Error: 0.14547037367441043
# Bias^2: 0.1454609430359009
# Var: 9.430638509549174e-06
# 0.14547037367441043 >= 0.1454609430359009 + 9.430638509549174e-06 = 0.14547037367441046
# ---------Cross Validation---------
# Error_sklearn: 0.2094190998024367
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 3.4646464646464654
# ---------Bootstrap---------
# Error: 0.1505547519393729
# Bias^2: 0.15054856775775372
# Var: 6.184181619214869e-06
# 0.1505547519393729 >= 0.15054856775775372 + 6.184181619214869e-06 = 0.15055475193937293
# ---------Cross Validation---------
# Error_sklearn: 0.2142100585732841
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 3.545454545454546
# ---------Bootstrap---------
# Error: 0.15488244428454342
# Bias^2: 0.15487874206227395
# Var: 3.7022222695153205e-06
# 0.15488244428454342 >= 0.15487874206227395 + 3.7022222695153205e-06 = 0.15488244428454345
# ---------Cross Validation---------
# Error_sklearn: 0.21861823094479446
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 3.626262626262627
# ---------Bootstrap---------
# Error: 0.1592732774423411
# Bias^2: 0.15927051873083392
# Var: 2.758711507200447e-06
# 0.1592732774423411 >= 0.15927051873083392 + 2.758711507200447e-06 = 0.15927327744234113
# ---------Cross Validation---------
# Error_sklearn: 0.22262355996462363
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 3.7070707070707076
# ---------Bootstrap---------
# Error: 0.16257228909062188
# Bias^2: 0.16256975923346725
# Var: 2.5298571546116403e-06
# 0.16257228909062188 >= 0.16256975923346725 + 2.5298571546116403e-06 = 0.16257228909062185
# ---------Cross Validation---------
# Error_sklearn: 0.2262204329795176
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 3.787878787878788
# ---------Bootstrap---------
# Error: 0.16586715020178838
# Bias^2: 0.1658657017099664
# Var: 1.448491821985511e-06
# 0.16586715020178838 >= 0.1658657017099664 + 1.448491821985511e-06 = 0.16586715020178838
# ---------Cross Validation---------
# Error_sklearn: 0.22941608630918617
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 3.8686868686868694
# ---------Bootstrap---------
# Error: 0.16869604686713993
# Bias^2: 0.16869484653703676
# Var: 1.200330103169557e-06
# 0.16869604686713993 >= 0.16869484653703676 + 1.200330103169557e-06 = 0.16869604686713993
# ---------Cross Validation---------
# Error_sklearn: 0.23222809170911254
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 3.94949494949495
# ---------Bootstrap---------
# Error: 0.1711701212558411
# Bias^2: 0.17116879595371212
# Var: 1.3253021289587408e-06
# 0.1711701212558411 >= 0.17116879595371212 + 1.3253021289587408e-06 = 0.17117012125584108
# ---------Cross Validation---------
# Error_sklearn: 0.23468151155806455
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 4.030303030303031
# ---------Bootstrap---------
# Error: 0.17333159152888694
# Bias^2: 0.1733310238120893
# Var: 5.677167976449674e-07
# 0.17333159152888694 >= 0.1733310238120893 + 5.677167976449674e-07 = 0.17333159152888697
# ---------Cross Validation---------
# Error_sklearn: 0.2368061555951535
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 4.111111111111112
# ---------Bootstrap---------
# Error: 0.175118355322531
# Bias^2: 0.1751179503116847
# Var: 4.050108462760319e-07
# 0.175118355322531 >= 0.1751179503116847 + 4.050108462760319e-07 = 0.17511835532253098
# ---------Cross Validation---------
# Error_sklearn: 0.23863420268614904
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 4.191919191919193
# ---------Bootstrap---------
# Error: 0.17672978863139432
# Bias^2: 0.17672952633448796
# Var: 2.6229690637543434e-07
# 0.17672978863139432 >= 0.17672952633448796 + 2.6229690637543434e-07 = 0.17672978863139435
# ---------Cross Validation---------
# Error_sklearn: 0.24019830661812286
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 4.272727272727273
# ---------Bootstrap---------
# Error: 0.17818580869354522
# Bias^2: 0.17818555237340783
# Var: 2.563201374424434e-07
# 0.17818580869354522 >= 0.17818555237340783 + 2.563201374424434e-07 = 0.17818580869354528
# ---------Cross Validation---------
# Error_sklearn: 0.24153020135757125
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 4.353535353535354
# ---------Bootstrap---------
# Error: 0.17915781582703866
# Bias^2: 0.17915772066749797
# Var: 9.515954068158579e-08
# 0.17915781582703866 >= 0.17915772066749797 + 9.515954068158579e-08 = 0.17915781582703866
# ---------Cross Validation---------
# Error_sklearn: 0.242659758466991
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 4.434343434343435
# ---------Bootstrap---------
# Error: 0.1802211901987804
# Bias^2: 0.18022105984079656
# Var: 1.3035798385930174e-07
# 0.1802211901987804 >= 0.18022105984079656 + 1.3035798385930174e-07 = 0.1802211901987804
# ---------Cross Validation---------
# Error_sklearn: 0.2436144193496109
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 4.515151515151516
# ---------Bootstrap---------
# Error: 0.18102865704877097
# Bias^2: 0.18102860162798054
# Var: 5.5420790402350486e-08
# 0.18102865704877097 >= 0.18102860162798054 + 5.5420790402350486e-08 = 0.18102865704877094
# ---------Cross Validation---------
# Error_sklearn: 0.24441891741741523
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 4.595959595959597
# ---------Bootstrap---------
# Error: 0.18171384452339795
# Bias^2: 0.1817137988303173
# Var: 4.569308063159055e-08
# 0.18171384452339795 >= 0.1817137988303173 + 4.569308063159055e-08 = 0.18171384452339792
# ---------Cross Validation---------
# Error_sklearn: 0.24509521096695464
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 4.676767676767677
# ---------Bootstrap---------
# Error: 0.18222581251158165
# Bias^2: 0.18222579220811697
# Var: 2.0303464695619682e-08
# 0.18222581251158165 >= 0.18222579220811697 + 2.0303464695619682e-08 = 0.18222581251158165
# ---------Cross Validation---------
# Error_sklearn: 0.245662559627974
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 4.757575757575758
# ---------Bootstrap---------
# Error: 0.18272656687382377
# Bias^2: 0.18272654624585744
# Var: 2.0627966381627508e-08
# 0.18272656687382377 >= 0.18272654624585744 + 2.0627966381627508e-08 = 0.18272656687382383
# ---------Cross Validation---------
# Error_sklearn: 0.24613769122817586
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 4.838383838383839
# ---------Bootstrap---------
# Error: 0.1831333451404248
# Bias^2: 0.1831333319507704
# Var: 1.318965440044128e-08
# 0.1831333451404248 >= 0.1831333319507704 + 1.318965440044128e-08 = 0.18313334514042479
# ---------Cross Validation---------
# Error_sklearn: 0.24653501922524237
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 4.91919191919192
# ---------Bootstrap---------
# Error: 0.18343511046402577
# Bias^2: 0.18343510277854844
# Var: 7.685477355462198e-09
# 0.18343511046402577 >= 0.18343510277854844 + 7.685477355462198e-09 = 0.1834351104640258
# ---------Cross Validation---------
# Error_sklearn: 0.24686688227492715
#
#
#
# Polynomial degree: 5
# Log10(Lambda): 5.0
# ---------Bootstrap---------
# Error: 0.18373478349176456
# Bias^2: 0.18373477788349085
# Var: 5.608273703489761e-09
# 0.18373478349176456 >= 0.18373477788349085 + 5.608273703489761e-09 = 0.18373478349176456
# ---------Cross Validation---------
# Error_sklearn: 0.24714378665285097
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-ad666ee90163> in <module>
#     111
#     112     min_error.append(min(estimated_mse_KFold))
# --> 113     min_lambdas.append(lambdas[estimated_mse_KFold.index(min(estimated_mse_KFold))])
#     114
#     115
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'
